# %% [markdown]
# # <font color="green">Selecting Rows and Columns</font>

# %% [markdown]
# ----------------------------------

# %% [markdown]
# ## Columns: Selecting and Working with Columns from a DataFrame
#
# ### Selecting Columns
# - You can select columns in Pandas using simple indexing with column names or with the `df[['column1', 'column2']]` syntax for multiple columns.
# - Selecting columns is a fundamental skill because it is often the first step in many data manipulation tasks.
#
# ### Working with Columns
# - Once columns are selected, they can be used for various operations such as computation, aggregation, and combination with other data.
# - Tasks such as renaming columns, handling missing values, or changing the data type of columns are essential for further analysis.
#
# ## Rows: Understanding the Difference Between `loc` and `iloc` Methods, and Selecting Rows from a DataFrame
#
# ### Difference Between `loc` and `iloc`
# - **`loc`**: Used to access a group of rows and columns by labels or a boolean array. It is label-based, requiring specification of the row and column labels.
# - **`iloc`**: Used for integer index-based access, requiring row and column indices for selection.
#
# ### Selecting Rows
# - Selecting rows is a process akin to selecting columns, typically accomplished using `loc` or `iloc`.
# - This is especially useful for filtering data based on some condition or when dealing with a specific range of indices.
#
# Understanding and mastering the manipulation of rows and columns in Pandas is pivotal for effective data cleaning, preparation, and analysis. These skills are integral to performing a broad spectrum of data analysis tasks with efficiency and precision.

# %% [markdown]
# ------------------

# %% [markdown]
# ### Key Concepts
# It is an essential part of working with data to able to select specific parts of a dataset. For example in order to fill in missing data in a particular column(s) this skill comes in very handy. This means that you should be very comfortable with the syntax of selecting rows and columns.

# %% [markdown]
# | Command                       | Description                                           |
# |-------------------------------|-------------------------------------------------------|
# | df[col]                       | select one column as a Series                         |
# | df[[col]]                     | select one column as a DataFrame                      |
# | df[[col1, col2, ... ]]        | select 2+ columns as a DataFrame                      |
# | df['column_name'] = new_values| assign new values to the column                        |
# | df.drop()                     | drop specified rows or columns                        |
# | df['column'].astype()         | cast a pandas column to a specified dtype             |
# | df.loc[row]                   | select one row as a Series by index                   |
# | df.loc[[row1, row2]]          | select 1+ rows as a DataFrame by index                |
# | df.loc[[row], [col]]          | select rows and columns as a DataFrame by index       |
# | df.iloc[a:b, c:d]             | select rows/columns by integer-location               |
# | df.set_index()                | set selected column as index                           |

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/penguins_simple.csv', sep=";")

# %%
# look at the dataframe

df
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    Adelie                39.1               18.7                181.0
# 1    Adelie                39.5               17.4                186.0
# 2    Adelie                40.3               18.0                195.0
# 3    Adelie                36.7               19.3                193.0
# 4    Adelie                39.3               20.6                190.0
# ..      ...                 ...                ...                  ...
# 328  Gentoo                47.2               13.7                214.0
# 329  Gentoo                46.8               14.3                215.0
# 330  Gentoo                50.4               15.7                222.0
# 331  Gentoo                45.2               14.8                212.0
# 332  Gentoo                49.9               16.1                213.0
#
#      Body Mass (g)     Sex
# 0           3750.0    MALE
# 1           3800.0  FEMALE
# 2           3250.0  FEMALE
# 3           3450.0  FEMALE
# 4           3650.0    MALE
# ..             ...     ...
# 328         4925.0  FEMALE
# 329         4850.0  FEMALE
# 330         5750.0    MALE
# 331         5200.0  FEMALE
# 332         5400.0    MALE
#
# [333 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Species', 'Culmen Length (mm)', 'Culmen Depth (mm)',
#        'Flipper Length (mm)', 'Body Mass (g)', 'Sex'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Species              333 non-null    object
#  1   Culmen Length (mm)   333 non-null    float64
#  2   Culmen Depth (mm)    333 non-null    float64
#  3   Flipper Length (mm)  333 non-null    float64
#  4   Body Mass (g)        333 non-null    float64
#  5   Sex                  333 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 15.7+ KB

# %% [markdown]
# ## 1. Columns

# %% [markdown]
# ### 1.1 Renaming the columns

# %%
df.columns =['species', 'culmen_length_mm','culmen_depth_mm', 'flipper_length_mm', 'body_mass_gg', 'sex']

# %%
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie              39.1             18.7              181.0
# 1    Adelie              39.5             17.4              186.0
# 2    Adelie              40.3             18.0              195.0
# 3    Adelie              36.7             19.3              193.0
# 4    Adelie              39.3             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo              47.2             13.7              214.0
# 329  Gentoo              46.8             14.3              215.0
# 330  Gentoo              50.4             15.7              222.0
# 331  Gentoo              45.2             14.8              212.0
# 332  Gentoo              49.9             16.1              213.0
#
#      body_mass_gg     sex
# 0          3750.0    MALE
# 1          3800.0  FEMALE
# 2          3250.0  FEMALE
# 3          3450.0  FEMALE
# 4          3650.0    MALE
# ..            ...     ...
# 328        4925.0  FEMALE
# 329        4850.0  FEMALE
# 330        5750.0    MALE
# 331        5200.0  FEMALE
# 332        5400.0    MALE
#
# [333 rows x 6 columns]

# %% [markdown]
# ### 1.2 Selecting a single column

# %%
# using single square brackets, we select a single column as a series
df['sex']
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 328    FEMALE
# 329    FEMALE
# 330      MALE
# 331    FEMALE
# 332      MALE
# Name: sex, Length: 333, dtype: object

# %% [markdown]
# This will extract the column as a pd.Series.

# %%
type(df['sex']) # as we learned it in the pandas encounter, it is pandas series
# Out:
# pandas.core.series.Series

# %%
# using double square brackets, we select a single columns as a dataframe
df[['sex']]
# Out:
#         sex
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 3    FEMALE
# 4      MALE
# ..      ...
# 328  FEMALE
# 329  FEMALE
# 330    MALE
# 331  FEMALE
# 332    MALE
#
# [333 rows x 1 columns]

# %%
type(df[['sex']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 1.3 Selecting Multiple Columns

# %%
# when selecting multiple columns, we HAVE to use double square brackets
# and we get a dataframe back
df[['species','culmen_length_mm','sex']]
# Out:
#     species  culmen_length_mm     sex
# 0    Adelie              39.1    MALE
# 1    Adelie              39.5  FEMALE
# 2    Adelie              40.3  FEMALE
# 3    Adelie              36.7  FEMALE
# 4    Adelie              39.3    MALE
# ..      ...               ...     ...
# 328  Gentoo              47.2  FEMALE
# 329  Gentoo              46.8  FEMALE
# 330  Gentoo              50.4    MALE
# 331  Gentoo              45.2  FEMALE
# 332  Gentoo              49.9    MALE
#
# [333 rows x 3 columns]

# %% [markdown]
# ### 1.4 Changing column types

# %%
df.dtypes # Notice that dataframes may contain different data types and that's why here it is dtypes
# Out:
# species               object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_gg         float64
# sex                   object
# dtype: object

# %%
# we sometimes need to change the data type of a column, that is usually part of data cleaning

df['culmen_length_mm'] = df['culmen_length_mm'].astype(int)

# %%
# Let's check the datatypes again
df.dtypes
# Out:
# species               object
# culmen_length_mm       int64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_gg         float64
# sex                   object
# dtype: object

# %% [markdown]
# ###  1.5 Creating columns

# %%
# Adding a new column
# For example, let's add a 'year_collected' column with a constant value
df['year_collected'] = 2024

# %% [markdown]
# How to round numbers in python:
# `round(<number_to_round>, <number_of_decimal_points>)`

# %%
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  year_collected
# 0          3750.0    MALE            2024
# 1          3800.0  FEMALE            2024
# 2          3250.0  FEMALE            2024
# 3          3450.0  FEMALE            2024
# 4          3650.0    MALE            2024
# ..            ...     ...             ...
# 328        4925.0  FEMALE            2024
# 329        4850.0  FEMALE            2024
# 330        5750.0    MALE            2024
# 331        5200.0  FEMALE            2024
# 332        5400.0    MALE            2024
#
# [333 rows x 7 columns]

# %%
df.dtypes
# Out:
# species               object
# culmen_length_mm       int64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_gg         float64
# sex                   object
# year_collected         int64
# dtype: object

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# count        333.000000       333.000000         333.000000    333.000000
# mean          43.561562        17.164865         200.966967   4207.057057
# std            5.478872         1.969235          14.015765    805.215802
# min           32.000000        13.100000         172.000000   2700.000000
# 25%           39.000000        15.600000         190.000000   3550.000000
# 50%           44.000000        17.300000         197.000000   4050.000000
# 75%           48.000000        18.700000         213.000000   4775.000000
# max           59.000000        21.500000         231.000000   6300.000000
#
#        year_collected
# count           333.0
# mean           2024.0
# std               0.0
# min            2024.0
# 25%            2024.0
# 50%            2024.0
# 75%            2024.0
# max            2024.0

# %%
# Convert body_mass_g from grams to kilograms, round to 2 decimal places, and create a new column

df['body_mass_kg'] = (df['body_mass_gg'] / 1000.0).round(2)

# %%
# Now, df includes a new column 'body_mass_kg' with the body mass in kilograms, rounded to 2 decimal places
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  year_collected  body_mass_kg
# 0          3750.0    MALE            2024          3.75
# 1          3800.0  FEMALE            2024          3.80
# 2          3250.0  FEMALE            2024          3.25
# 3          3450.0  FEMALE            2024          3.45
# 4          3650.0    MALE            2024          3.65
# ..            ...     ...             ...           ...
# 328        4925.0  FEMALE            2024          4.92
# 329        4850.0  FEMALE            2024          4.85
# 330        5750.0    MALE            2024          5.75
# 331        5200.0  FEMALE            2024          5.20
# 332        5400.0    MALE            2024          5.40
#
# [333 rows x 8 columns]

# %% [markdown]
# ### 1.6 Dropping columns

# %%
# dropping a single column

df.drop('year_collected', axis='columns')
#df.drop('year_collected', axis=1)
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  body_mass_kg
# 0          3750.0    MALE          3.75
# 1          3800.0  FEMALE          3.80
# 2          3250.0  FEMALE          3.25
# 3          3450.0  FEMALE          3.45
# 4          3650.0    MALE          3.65
# ..            ...     ...           ...
# 328        4925.0  FEMALE          4.92
# 329        4850.0  FEMALE          4.85
# 330        5750.0    MALE          5.75
# 331        5200.0  FEMALE          5.20
# 332        5400.0    MALE          5.40
#
# [333 rows x 7 columns]

# %%
# note that the dataframe did not change!
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  year_collected  body_mass_kg
# 0          3750.0    MALE            2024          3.75
# 1          3800.0  FEMALE            2024          3.80
# 2          3250.0  FEMALE            2024          3.25
# 3          3450.0  FEMALE            2024          3.45
# 4          3650.0    MALE            2024          3.65
# ..            ...     ...             ...           ...
# 328        4925.0  FEMALE            2024          4.92
# 329        4850.0  FEMALE            2024          4.85
# 330        5750.0    MALE            2024          5.75
# 331        5200.0  FEMALE            2024          5.20
# 332        5400.0    MALE            2024          5.40
#
# [333 rows x 8 columns]

# %% [markdown]
# Uh-oh! Dropping returned a (changed) copy of the dataframe, but didn't change the original!
#
# To make the changes stick, you can:
# * assign the result to another dataframe
# * use the `inplace=True` parameter

# %%
# assign the result to another datafram
df_new = df.drop('year_collected', axis=1) # notice that instead of columns we used axis=1 which is the same thing

# %%
df_new
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  body_mass_kg
# 0          3750.0    MALE          3.75
# 1          3800.0  FEMALE          3.80
# 2          3250.0  FEMALE          3.25
# 3          3450.0  FEMALE          3.45
# 4          3650.0    MALE          3.65
# ..            ...     ...           ...
# 328        4925.0  FEMALE          4.92
# 329        4850.0  FEMALE          4.85
# 330        5750.0    MALE          5.75
# 331        5200.0  FEMALE          5.20
# 332        5400.0    MALE          5.40
#
# [333 rows x 7 columns]

# %%
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  year_collected  body_mass_kg
# 0          3750.0    MALE            2024          3.75
# 1          3800.0  FEMALE            2024          3.80
# 2          3250.0  FEMALE            2024          3.25
# 3          3450.0  FEMALE            2024          3.45
# 4          3650.0    MALE            2024          3.65
# ..            ...     ...             ...           ...
# 328        4925.0  FEMALE            2024          4.92
# 329        4850.0  FEMALE            2024          4.85
# 330        5750.0    MALE            2024          5.75
# 331        5200.0  FEMALE            2024          5.20
# 332        5400.0    MALE            2024          5.40
#
# [333 rows x 8 columns]

# %%
# to drop from the dataframe we use the inplace=True parameter
df.drop('year_collected', axis='columns', inplace=True)

# %%
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  body_mass_kg
# 0          3750.0    MALE          3.75
# 1          3800.0  FEMALE          3.80
# 2          3250.0  FEMALE          3.25
# 3          3450.0  FEMALE          3.45
# 4          3650.0    MALE          3.65
# ..            ...     ...           ...
# 328        4925.0  FEMALE          4.92
# 329        4850.0  FEMALE          4.85
# 330        5750.0    MALE          5.75
# 331        5200.0  FEMALE          5.20
# 332        5400.0    MALE          5.40
#
# [333 rows x 7 columns]

# %% [markdown]
# ## 2. Selecting rows (and columns): `.loc[]` and `.iloc[]` methods

# %% [markdown]
# A brief slicing recap:

# %%
a = [1,2,3,4,5,6]

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Reminder: slicing syntax is `a[start:end:step]`
# * If not specified, `start` is the beginning of the list.
# * If not specified, `end` is the end of the list.
# * You can use minus to count from the back, e.g. the second element from the back is `a[-2]`
# * If not specified, `step` is 1.

# %%
# select first 4 numbers
a[:4]
# Out:
# [1, 2, 3, 4]

# %%
a[1:4]
# Out:
# [2, 3, 4]

# %%
# what does this do?
a[::3]
# it gives us every third element in the list
# Out:
# [1, 4]

# %% [markdown]
# ## Selecting rows with .loc[row_index]

# %% [markdown]
# ### Here's a quick guide on how to use `loc[]`:
#
# `loc[]` is a versatile selection method in Pandas that allows you to specify rows and columns to access based on their labels.
#
# - **Select a single row:** `df.loc['index_label']`
#
#   Accesses the row with the specified label.
#
# - **Select multiple rows:** `df.loc[['label1', 'label2']]`
#
#   Retrieves multiple rows with the given labels.
#
# - **Select rows by range of labels:** `df.loc['label1':'label3']`
#
#   Selects all rows between and including the specified label range.
#
# - **Conditional selection:** `df.loc[df['column'] > value]`
#
#   Filters rows based on a condition applied to column values.
#
# - **Select specific rows and columns:** `df.loc[['row1', 'row2'], ['column1', 'column2']]`
#
#   Selects particular rows and columns by specifying their labels.
#
# #### Important Notes:
# - `loc[]` operates on the DataFrame's index labels and column names. It is particularly well-suited for DataFrames where these labels are meaningful.
# - It's often used when the operations are based on the data's content rather than its position.
# - When using `loc[]` to select rows by a range of labels, the end label is included in the output, which is different from typical Python slicing.
#
# Mastering `loc[]` will enhance your data manipulation capabilities, allowing you to efficiently access and modify your data based on its labels.

# %%
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  body_mass_kg
# 0          3750.0    MALE          3.75
# 1          3800.0  FEMALE          3.80
# 2          3250.0  FEMALE          3.25
# 3          3450.0  FEMALE          3.45
# 4          3650.0    MALE          3.65
# ..            ...     ...           ...
# 328        4925.0  FEMALE          4.92
# 329        4850.0  FEMALE          4.85
# 330        5750.0    MALE          5.75
# 331        5200.0  FEMALE          5.20
# 332        5400.0    MALE          5.40
#
# [333 rows x 7 columns]

# %%
# Example 1: Select the first row
df.loc[0, :]
# Out:
# species              Adelie
# culmen_length_mm         39
# culmen_depth_mm        18.7
# flipper_length_mm     181.0
# body_mass_gg         3750.0
# sex                    MALE
# body_mass_kg           3.75
# Name: 0, dtype: object

# %%
# Example 2: Select first two rows
df.loc[0:1,:]
# Out:
#   species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# 0  Adelie                39             18.7              181.0        3750.0
# 1  Adelie                39             17.4              186.0        3800.0
#
#       sex  body_mass_kg
# 0    MALE          3.75
# 1  FEMALE          3.80

# %%
df.loc[0:1]
# Out:
#   species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# 0  Adelie                39             18.7              181.0        3750.0
# 1  Adelie                39             17.4              186.0        3800.0
#
#       sex  body_mass_kg
# 0    MALE          3.75
# 1  FEMALE          3.80

# %%
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  body_mass_kg
# 0          3750.0    MALE          3.75
# 1          3800.0  FEMALE          3.80
# 2          3250.0  FEMALE          3.25
# 3          3450.0  FEMALE          3.45
# 4          3650.0    MALE          3.65
# ..            ...     ...           ...
# 328        4925.0  FEMALE          4.92
# 329        4850.0  FEMALE          4.85
# 330        5750.0    MALE          5.75
# 331        5200.0  FEMALE          5.20
# 332        5400.0    MALE          5.40
#
# [333 rows x 7 columns]

# %%
df.loc[df['culmen_length_mm'] > 40]
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 7    Adelie                41             17.6              182.0
# 12   Adelie                42             20.7              197.0
# 14   Adelie                46             21.5              194.0
# 32   Adelie                42             18.5              180.0
# 38   Adelie                44             19.7              196.0
# ..      ...               ...              ...                ...
# 328  Gentoo                47             13.7              214.0
# 329  Gentoo                46             14.3              215.0
# 330  Gentoo                50             15.7              222.0
# 331  Gentoo                45             14.8              212.0
# 332  Gentoo                49             16.1              213.0
#
#      body_mass_gg     sex  body_mass_kg
# 7          3200.0  FEMALE          3.20
# 12         4500.0    MALE          4.50
# 14         4200.0    MALE          4.20
# 32         3550.0  FEMALE          3.55
# 38         4400.0    MALE          4.40
# ..            ...     ...           ...
# 328        4925.0  FEMALE          4.92
# 329        4850.0  FEMALE          4.85
# 330        5750.0    MALE          5.75
# 331        5200.0  FEMALE          5.20
# 332        5400.0    MALE          5.40
#
# [218 rows x 7 columns]

# %%
#If you want to select all rows where the species is "Adelie", you can use:

adelie_penguins = df.loc[df['species'] == 'Adelie']
adelie_penguins
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie                39             18.7              181.0
# 1    Adelie                39             17.4              186.0
# 2    Adelie                40             18.0              195.0
# 3    Adelie                36             19.3              193.0
# 4    Adelie                39             20.6              190.0
# ..      ...               ...              ...                ...
# 141  Adelie                36             18.4              184.0
# 142  Adelie                36             17.8              195.0
# 143  Adelie                37             18.1              193.0
# 144  Adelie                36             17.1              187.0
# 145  Adelie                41             18.5              201.0
#
#      body_mass_gg     sex  body_mass_kg
# 0          3750.0    MALE          3.75
# 1          3800.0  FEMALE          3.80
# 2          3250.0  FEMALE          3.25
# 3          3450.0  FEMALE          3.45
# 4          3650.0    MALE          3.65
# ..            ...     ...           ...
# 141        3475.0  FEMALE          3.48
# 142        3450.0  FEMALE          3.45
# 143        3750.0    MALE          3.75
# 144        3700.0  FEMALE          3.70
# 145        4000.0    MALE          4.00
#
# [146 rows x 7 columns]

# %%
chinstrap=df.loc[df['species']== 'Chinstrap']
chinstrap
# Out:
#        species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 146  Chinstrap                46             17.9              192.0
# 147  Chinstrap                50             19.5              196.0
# 148  Chinstrap                51             19.2              193.0
# 149  Chinstrap                45             18.7              188.0
# 150  Chinstrap                52             19.8              197.0
# ..         ...               ...              ...                ...
# 209  Chinstrap                55             19.8              207.0
# 210  Chinstrap                43             18.1              202.0
# 211  Chinstrap                49             18.2              193.0
# 212  Chinstrap                50             19.0              210.0
# 213  Chinstrap                50             18.7              198.0
#
#      body_mass_gg     sex  body_mass_kg
# 146        3500.0  FEMALE          3.50
# 147        3900.0    MALE          3.90
# 148        3650.0    MALE          3.65
# 149        3525.0  FEMALE          3.52
# 150        3725.0    MALE          3.72
# ..            ...     ...           ...
# 209        4000.0    MALE          4.00
# 210        3400.0  FEMALE          3.40
# 211        3775.0    MALE          3.78
# 212        4100.0    MALE          4.10
# 213        3775.0  FEMALE          3.78
#
# [68 rows x 7 columns]

# %% [markdown]
# **_How does loc[ ] work?_**
#
# - Notice that loc is including both 0 and 1 rows
# - Loc is using the labels of the row. Let's make some changes to understand it better

# %%
# changing the index column of the dataframe
df.set_index('species', inplace=True) 

# It is also possible to assign a column as index, when we are reading the data

# %%
df.head()
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             18.7              181.0        3750.0
# Adelie                 39             17.4              186.0        3800.0
# Adelie                 40             18.0              195.0        3250.0
# Adelie                 36             19.3              193.0        3450.0
# Adelie                 39             20.6              190.0        3650.0
#
#             sex  body_mass_kg
# species
# Adelie     MALE          3.75
# Adelie   FEMALE          3.80
# Adelie   FEMALE          3.25
# Adelie   FEMALE          3.45
# Adelie     MALE          3.65

# %%
df.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_gg', 'sex', 'body_mass_kg'],
#       dtype='object')

# %%
df.head(2)
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             18.7              181.0        3750.0
# Adelie                 39             17.4              186.0        3800.0
#
#             sex  body_mass_kg
# species
# Adelie     MALE          3.75
# Adelie   FEMALE          3.80

# %%
df.tail()
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Gentoo                 47             13.7              214.0        4925.0
# Gentoo                 46             14.3              215.0        4850.0
# Gentoo                 50             15.7              222.0        5750.0
# Gentoo                 45             14.8              212.0        5200.0
# Gentoo                 49             16.1              213.0        5400.0
#
#             sex  body_mass_kg
# species
# Gentoo   FEMALE          4.92
# Gentoo   FEMALE          4.85
# Gentoo     MALE          5.75
# Gentoo   FEMALE          5.20
# Gentoo     MALE          5.40

# %%
df.tail(3)
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Gentoo                 50             15.7              222.0        5750.0
# Gentoo                 45             14.8              212.0        5200.0
# Gentoo                 49             16.1              213.0        5400.0
#
#             sex  body_mass_kg
# species
# Gentoo     MALE          5.75
# Gentoo   FEMALE          5.20
# Gentoo     MALE          5.40

# %%
# Example 1: Select the second row

# we will get an error now, because we changed the index labels in species . we should give the new labels
df.loc[1, :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File index.pyx:204, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:209, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 4
#       1 # Example 1: Select the second row
#       2
#       3 # we will get an error now, because we changed the index labels in species . we should give the new labels
# ----> 4 df.loc[1, :]
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1330, in _LocIndexer._getitem_tuple(self, tup)
#    1328 with suppress(IndexingError):
#    1329     tup = self._expand_ellipsis(tup)
# -> 1330     return self._getitem_lowerdim(tup)
#    1332 # no multi-index, so validate all of the indexers
#    1333 tup = self._validate_tuple_indexer(tup)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1039, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1035 for i, key in enumerate(tup):
#    1036     if is_label_like(key):
#    1037         # We don't need to check for tuples here because those are
#    1038         #  caught by the _is_nested_tuple_indexer check above.
# -> 1039         section = self._getitem_axis(key, axis=i)
#    1041         # We should never have a scalar section here, because
#    1042         #  _getitem_lowerdim is only called after a check for
#    1043         #  is_scalar_access, which that would be.
#    1044         if section.ndim == self.ndim:
#    1045             # we're in the middle of slicing through a MultiIndex
#    1046             # revise the key wrt to `section` by inserting an _NS
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 1

# %%
df
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             18.7              181.0        3750.0
# Adelie                 39             17.4              186.0        3800.0
# Adelie                 40             18.0              195.0        3250.0
# Adelie                 36             19.3              193.0        3450.0
# Adelie                 39             20.6              190.0        3650.0
# ...                   ...              ...                ...           ...
# Gentoo                 47             13.7              214.0        4925.0
# Gentoo                 46             14.3              215.0        4850.0
# Gentoo                 50             15.7              222.0        5750.0
# Gentoo                 45             14.8              212.0        5200.0
# Gentoo                 49             16.1              213.0        5400.0
#
#             sex  body_mass_kg
# species
# Adelie     MALE          3.75
# Adelie   FEMALE          3.80
# Adelie   FEMALE          3.25
# Adelie   FEMALE          3.45
# Adelie     MALE          3.65
# ...         ...           ...
# Gentoo   FEMALE          4.92
# Gentoo   FEMALE          4.85
# Gentoo     MALE          5.75
# Gentoo   FEMALE          5.20
# Gentoo     MALE          5.40
#
# [333 rows x 6 columns]

# %%
df.loc['Adelie', :] # the new index labels is the species. loc uses the labels.
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             18.7              181.0        3750.0
# Adelie                 39             17.4              186.0        3800.0
# Adelie                 40             18.0              195.0        3250.0
# Adelie                 36             19.3              193.0        3450.0
# Adelie                 39             20.6              190.0        3650.0
# ...                   ...              ...                ...           ...
# Adelie                 36             18.4              184.0        3475.0
# Adelie                 36             17.8              195.0        3450.0
# Adelie                 37             18.1              193.0        3750.0
# Adelie                 36             17.1              187.0        3700.0
# Adelie                 41             18.5              201.0        4000.0
#
#             sex  body_mass_kg
# species
# Adelie     MALE          3.75
# Adelie   FEMALE          3.80
# Adelie   FEMALE          3.25
# Adelie   FEMALE          3.45
# Adelie     MALE          3.65
# ...         ...           ...
# Adelie   FEMALE          3.48
# Adelie   FEMALE          3.45
# Adelie     MALE          3.75
# Adelie   FEMALE          3.70
# Adelie     MALE          4.00
#
# [146 rows x 6 columns]

# %%
# Example 2: Select rows that contain Adelie and Chinstrap Species
df.loc['Adelie':'Chinstrap', :]
# Out:
#            culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                   39             18.7              181.0        3750.0
# Adelie                   39             17.4              186.0        3800.0
# Adelie                   40             18.0              195.0        3250.0
# Adelie                   36             19.3              193.0        3450.0
# Adelie                   39             20.6              190.0        3650.0
# ...                     ...              ...                ...           ...
# Chinstrap                55             19.8              207.0        4000.0
# Chinstrap                43             18.1              202.0        3400.0
# Chinstrap                49             18.2              193.0        3775.0
# Chinstrap                50             19.0              210.0        4100.0
# Chinstrap                50             18.7              198.0        3775.0
#
#               sex  body_mass_kg
# species
# Adelie       MALE          3.75
# Adelie     FEMALE          3.80
# Adelie     FEMALE          3.25
# Adelie     FEMALE          3.45
# Adelie       MALE          3.65
# ...           ...           ...
# Chinstrap    MALE          4.00
# Chinstrap  FEMALE          3.40
# Chinstrap    MALE          3.78
# Chinstrap    MALE          4.10
# Chinstrap  FEMALE          3.78
#
# [214 rows x 6 columns]

# %%
df.loc['Adelie':'Gentoo', :]
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             18.7              181.0        3750.0
# Adelie                 39             17.4              186.0        3800.0
# Adelie                 40             18.0              195.0        3250.0
# Adelie                 36             19.3              193.0        3450.0
# Adelie                 39             20.6              190.0        3650.0
# ...                   ...              ...                ...           ...
# Gentoo                 47             13.7              214.0        4925.0
# Gentoo                 46             14.3              215.0        4850.0
# Gentoo                 50             15.7              222.0        5750.0
# Gentoo                 45             14.8              212.0        5200.0
# Gentoo                 49             16.1              213.0        5400.0
#
#             sex  body_mass_kg
# species
# Adelie     MALE          3.75
# Adelie   FEMALE          3.80
# Adelie   FEMALE          3.25
# Adelie   FEMALE          3.45
# Adelie     MALE          3.65
# ...         ...           ...
# Gentoo   FEMALE          4.92
# Gentoo   FEMALE          4.85
# Gentoo     MALE          5.75
# Gentoo   FEMALE          5.20
# Gentoo     MALE          5.40
#
# [333 rows x 6 columns]

# %% [markdown]
# ## Selecting rows with .iloc[integer_position]

# %% [markdown]
# + Te iloc[] function in pandas is used for integer-location based indexing, which means it selects rows and columns using integer indices. Here are some scenarios when you might use iloc():
#
# ## iloc[] Usage Guide
#
# `iloc[]` provides flexibility in data selection within pandas DataFrames through integer indexing. Below are some common ways to utilize `iloc[]`:
#
# - **Select a Single Row**: `df.iloc[5]`
#   - This accesses the sixth row in the DataFrame since indexing starts at 0.
#
# - **Select Multiple Rows**: `df.iloc[5:10]`
#   - Retrieves rows 6 to 10, including the start index but excluding the end index.
#
# - **Select Rows and Specific Columns**: `df.iloc[5:10, 0:2]`
#   - Selects rows 6 to 10 and the first two columns.
#
# - **Select Specific Rows and All Columns**: `df.iloc[[1, 3, 7], :]`
#   - Accesses rows 2, 4, and 8 across all columns.
#
# ## Additional Tips
#
# - Remember that `iloc[]` uses zero-based indexing, similar to indexing in native Python lists or numpy arrays.
#
# - The end index in a range is excluded, aligning with standard Python slicing notation.
#
# - With `iloc[]`, you can also access rows and columns in reverse order by employing negative indices.

# %%
df
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             18.7              181.0        3750.0
# Adelie                 39             17.4              186.0        3800.0
# Adelie                 40             18.0              195.0        3250.0
# Adelie                 36             19.3              193.0        3450.0
# Adelie                 39             20.6              190.0        3650.0
# ...                   ...              ...                ...           ...
# Gentoo                 47             13.7              214.0        4925.0
# Gentoo                 46             14.3              215.0        4850.0
# Gentoo                 50             15.7              222.0        5750.0
# Gentoo                 45             14.8              212.0        5200.0
# Gentoo                 49             16.1              213.0        5400.0
#
#             sex  body_mass_kg
# species
# Adelie     MALE          3.75
# Adelie   FEMALE          3.80
# Adelie   FEMALE          3.25
# Adelie   FEMALE          3.45
# Adelie     MALE          3.65
# ...         ...           ...
# Gentoo   FEMALE          4.92
# Gentoo   FEMALE          4.85
# Gentoo     MALE          5.75
# Gentoo   FEMALE          5.20
# Gentoo     MALE          5.40
#
# [333 rows x 6 columns]

# %%
df.iloc[5] #(selects the row at position 5)
# Out:
# culmen_length_mm         38
# culmen_depth_mm        17.8
# flipper_length_mm     181.0
# body_mass_gg         3625.0
# sex                  FEMALE
# body_mass_kg           3.62
# Name: Adelie, dtype: object

# %%
df.iloc[0:2]
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             18.7              181.0        3750.0
# Adelie                 39             17.4              186.0        3800.0
#
#             sex  body_mass_kg
# species
# Adelie     MALE          3.75
# Adelie   FEMALE          3.80

# %%
df.iloc['Adelie':'Gentoo', :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.iloc['Adelie':'Gentoo', :]
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1656, in _iLocIndexer._getitem_tuple(self, tup)
#    1653 with suppress(IndexingError):
#    1654     return self._getitem_lowerdim(tup)
# -> 1656 return self._getitem_tuple_same_dim(tup)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:994, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     991 if com.is_null_slice(key):
#     992     continue
# --> 994 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     995 # We should never have retval.ndim < self.ndim, as that should
#     996 #  be handled by the _getitem_lowerdim call above.
#     997 assert retval.ndim == self.ndim
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1691, in _iLocIndexer._getitem_axis(self, key, axis)
#    1685     raise IndexError(
#    1686         "DataFrame indexer is not allowed for .iloc\n"
#    1687         "Consider using .loc for automatic alignment."
#    1688     )
#    1690 if isinstance(key, slice):
# -> 1691     return self._get_slice_axis(key, axis=axis)
#    1693 if is_iterator(key):
#    1694     key = list(key)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1726, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1723     return obj.copy(deep=False)
#    1725 labels = obj._get_axis(axis)
# -> 1726 labels._validate_positional_slice(slice_obj)
#    1727 return self.obj._slice(slice_obj, axis=axis)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:4196, in Index._validate_positional_slice(self, key)
#    4190 @final
#    4191 def _validate_positional_slice(self, key: slice) -> None:
#    4192     """
#    4193     For positional indexing, a slice must have either int or None
#    4194     for each of start, stop, and step.
#    4195     """
# -> 4196     self._validate_indexer("positional", key.start, "iloc")
#    4197     self._validate_indexer("positional", key.stop, "iloc")
#    4198     self._validate_indexer("positional", key.step, "iloc")
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6637, in Index._validate_indexer(self, form, key, kind)
#    6632 """
#    6633 If we are positional indexer, validate that we have appropriate
#    6634 typed bounds must be an integer.
#    6635 """
#    6636 if not lib.is_int_or_none(key):
# -> 6637     self._raise_invalid_indexer(form, key)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:4306, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4304 if reraise is not lib.no_default:
#    4305     raise TypeError(msg) from reraise
# -> 4306 raise TypeError(msg)
#
# TypeError: cannot do positional indexing on Index with these indexers [Adelie] of type str

# %%
df.iloc[5:10] #(selects rows at positions 5 to 9)
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 38             17.8              181.0        3625.0
# Adelie                 39             19.6              195.0        4675.0
# Adelie                 41             17.6              182.0        3200.0
# Adelie                 38             21.2              191.0        3800.0
# Adelie                 34             21.1              198.0        4400.0
#
#             sex  body_mass_kg
# species
# Adelie   FEMALE          3.62
# Adelie     MALE          4.68
# Adelie   FEMALE          3.20
# Adelie     MALE          3.80
# Adelie     MALE          4.40

# %%
df.iloc[5:10, 0:2]  #(selects rows at positions 5 to 9 and columns at positions 0 to 1)
# Out:
#          culmen_length_mm  culmen_depth_mm
# species
# Adelie                 38             17.8
# Adelie                 39             19.6
# Adelie                 41             17.6
# Adelie                 38             21.2
# Adelie                 34             21.1

# %%
df.iloc[[1, 3, 300], :] #(selects rows at positions 1, 3, and 7, along with all columns)
# Out:
#          culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_gg  \
# species
# Adelie                 39             17.4              186.0        3800.0
# Adelie                 36             19.3              193.0        3450.0
# Gentoo                 47             14.0              212.0        4875.0
#
#             sex  body_mass_kg
# species
# Adelie   FEMALE          3.80
# Adelie   FEMALE          3.45
# Gentoo   FEMALE          4.88

# %% [markdown]
# # Recap: .loc vs .iloc in Pandas
#
# Pandas offers two powerful methods for data selection within DataFrames, `.loc` and `.iloc`, each catering to different selection criteria:
#
# ## .loc Method (Label-based Selection)
#
# - **Label-based Selection**: Utilizes row and column **labels** for data access.
# - **Syntax**: `df.loc[row_label, column_label]`
#   - You specify the rows and columns by using their labels.
#   - This method is ideal when you know the exact labels of the rows and columns you're interested in.
#
# ## .iloc Method (Integer Position-based Selection)
#
# - **Integer Position-based Selection**: Relies on **integer position values** (0-based) for selecting rows and columns.
# - **Syntax**: `df.iloc[row_position, column_position]`
#   - Rows and columns are specified by their integer index positions.
#   - This approach is useful when you want to access data based on its position in the DataFrame, similar to indexing in Python lists or arrays.

# %% [markdown]
# ## lambda

# %%
def adding():
    a=int(input("give me a number"))
    b=int(input("give me another number"))
    return a+b

# %%
adding()
# Out:
# give me a number 3
# give me another number 5
# 8

# %%
h = lambda a,b: a+b

# %%
h(3,2)
# Out:
# 5
